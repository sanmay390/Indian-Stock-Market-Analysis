# %%
#!pip install fbprophet
from fbprophet import Prophet
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
from nsepy import get_history
from datetime import date
sbi = get_history(symbol='SBIN',
                        start=date(2021,1,1), 
                        end=date(2021,2,15))

# %%
sbi
# = pd.to_datetime(df['ds'])
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2021-01-01   SBIN     EQ      274.95  274.90  280.00  274.40  279.05  279.40
# 2021-01-04   SBIN     EQ      279.40  281.85  283.90  277.75  281.10  281.05
# 2021-01-05   SBIN     EQ      281.05  278.05  282.45  277.00  281.40  281.75
# 2021-01-06   SBIN     EQ      281.75  283.00  289.15  281.40  283.90  285.05
# 2021-01-07   SBIN     EQ      285.05  289.00  291.80  287.00  288.00  287.70
# 2021-01-08   SBIN     EQ      287.70  290.10  291.40  285.20  285.90  286.00
# 2021-01-11   SBIN     EQ      286.00  288.00  288.20  279.60  282.80  282.50
# 2021-01-12   SBIN     EQ      282.50  280.00  293.85  277.90  293.20  292.50
# 2021-01-13   SBIN     EQ      292.50  296.00  308.00  294.50  305.95  306.80
# 2021-01-14   SBIN     EQ      306.80  306.70  309.25  303.80  307.70  307.25
# 2021-01-15   SBIN     EQ      307.25  306.80  310.90  301.30  303.95  303.85
# ...

# %%
#type(sbi)
df=pd.DataFrame(sbi['Close','Volume'])
df

# %%
# model1=Prophet(interval_width=0.95)

# %%
banknifty.plot()
plt.show()

# %%
m=Prophet()
m.fit(df)

# %%
future = m.make_future_dataframe(periods=365)
future.tail()

# %%
print (pd.to_datetime(df_sub['year'].astype(str)  + df_sub['Months'], format='%Y%B'))

# %%
import os
from dotenv import load_dotenv
import typing
import fmpsdk

# Actual API key is stored in a .env file.  Not good to store API key directly in script.
# load_dotenv()
# apikey = os.environ.get("78236beb8b35ee908ef23934d4917e93")

# Company Valuation Methods
symbol: str = "AAP "
print(f"Company Profile: {fmpsdk.company_profile(apikey='78236beb8b35ee908ef23934d4917e93', symbol=symbol)}")

# %%
# !pip install selenium

# %%
import nse50bse30
nse50 = nse50bse30.getNSE50()
nse50

# %%
import pandas as pd

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains

# %%
url = "https://www.nseindia.com/"
driver = webdriver.Chrome("C:/Users/SANMAY/Downloads/chromedriver_win32 (1)/chromedriver.exe")
driver.get(url)
import time
time.sleep(5)

# %%
action = ActionChains(driver)

live_market_section = driver.find_element_by_xpath('//*[@id="main_livemkt"]/a')
action.move_to_element(live_market_section).perform()

# %%
equity_derivatives = driver.find_element_by_xpath('//*[@id="main_livewth_deri"]/a')
equity_derivatives.click()

# %%
import pandas as pd
data = pd.read_excel('NiftyBank MW.xlsx')

# %%
df=pd.DataFrame(data)

# %%
df

# %%
# i=0;
n=10;
while(n):
    n-=1;
    if(n%2==0):
        continue;
    print(n);
# Out:
# 9
# 7
# 5
# 3
# 1
